# %% [markdown]
# <a href="https://colab.research.google.com/github/Bbarrett636/test-repo/blob/master/tensorflow_style_transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hwalsuklee/tensorflow-style-transfer.git
# Out:
# Cloning into 'tensorflow-style-transfer'...
# remote: Enumerating objects: 92, done.
# remote: Total 92 (delta 0), reused 0 (delta 0), pack-reused 92
# Unpacking objects: 100% (92/92), done.

# %%
# !mkdir pre_trained_model

# %%
# !mv imagenet-vgg-verydeep-19.mat pre_trained_model

# %%
# !python tensorflow-style-transfer/run_main.py --content tensorflow-style-transfer/images/tubingen.jpg --style tensorflow-style-transfer/images/starry-night.jpg --output result.jpg
# Out:
# 2018-11-25 17:19:42.043114: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-11-25 17:19:42.043676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-11-25 17:19:42.043717: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-11-25 17:19:43.096525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-11-25 17:19:43.096584: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-11-25 17:19:43.096610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# ...

# %%
# !mv pollock.jpg tensorflow-style-transfer/images

# %%
# !python tensorflow-style-transfer/run_main.py --content tensorflow-style-transfer/images/fullsizeoutput_74f.jpeg --style tensorflow-style-transfer/images/pollock.jpg --output tesla_pollock.jpg
# Out:
# 2018-11-25 22:09:01.950791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-11-25 22:09:01.951309: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-11-25 22:09:01.951367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-11-25 22:09:02.374805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-11-25 22:09:02.374892: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-11-25 22:09:02.374921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# ...
